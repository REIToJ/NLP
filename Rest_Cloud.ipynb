# %%
# !pip install matplotlib
# !pip install wordcloud
# !pip install stop_words

import re
import matplotlib.pyplot as plt

import numpy as np
from PIL import Image
from wordcloud import WordCloud
from stop_words import get_stop_words

# %matplotlib inline

file = open('Rest_Esse.txt', "r", encoding="utf-8")
text = file.read()

text = re.sub(r'==.*?==+', '', text)
text = text.replace('\n', '')
    
mask = np.array(Image.open('loc.png'))

STOPWORDS_RU = get_stop_words('russian')

def plot_cloud(wordcloud):
    plt.figure(figsize=(40, 30))
    plt.imshow(wordcloud) 
    plt.axis("off")

wordcloud = WordCloud(width = 2000, 
                      height = 1500, 
                      random_state=1, 
                      background_color='white', 
                      colormap='Set2', 
                      collocations=False, 
                      stopwords = STOPWORDS_RU, 
                      mask=mask).generate(text)
                      
plot_cloud(wordcloud)

wordcloud.to_file('result.png')
# Out:
# Requirement already satisfied: matplotlib in d:\mambaforge\lib\site-packages (3.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\mambaforge\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\mambaforge\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\mambaforge\lib\site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\mambaforge\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in d:\mambaforge\lib\site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\mambaforge\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in d:\mambaforge\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: wordcloud in d:\mambaforge\lib\site-packages (1.8.1)
# Requirement already satisfied: matplotlib in d:\mambaforge\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: numpy>=1.6.1 in d:\mambaforge\lib\site-packages (from wordcloud) (1.21.2)
# Requirement already satisfied: pillow in d:\mambaforge\lib\site-packages (from wordcloud) (8.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\mambaforge\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\mambaforge\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\mambaforge\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in d:\mambaforge\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: six in d:\mambaforge\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: stop_words in d:\mambaforge\lib\site-packages (2018.7.23)
